# %% [markdown]
# <a href="https://colab.research.google.com/github/byancalourenco/Aulas_PA/blob/main/exercicios_fluxograma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INTRODUÇÃO À LÓGICA DE PROGRAMAÇÃO

# %% [markdown]
# 1 -

# %%
# Entrada
VALOR = float(input("Digite o valor da peça: "))
QTDE = float(input("Digite a quantidade de peças: "))

# Processamento
VT = QTDE * VALOR

# Saída
print ("O valor total é: ",VT)
# Out:
# Digite o valor da peça: 20
# Digite a quantidade de peças: 56
# O valor total é:  1120.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2 -

# %%
# Coletando valores para as variáveis
QTDEMIN = float(input("Digite a quantidade mínima do estoque: "))
QTDEMAXIMA = float(input("Digite a quantidade máxima do estoque: "))

# Processamento
ESTOQUEMEDIO = (QTDEMIN + QTDEMAXIMA)/2

# Saída
print ("O valor médio do estoque é: ",ESTOQUEMEDIO)
# Out:
# Digite a quantidade mínima do estoque: 400
# Digite a quantidade máxima do estoque: 5680
# O valor médio do estoque é:  3040.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3 - teste de mesa do exercício anterior

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # DESENVOLVENDO ALGORITIMOS

# %% [markdown]
# 1 -

# %%
# Coletando valores para as variáveis
dolar = float(input("Digite o valor da cotação do dólar: "))
valor = float(input("Digite o valor que deseja converter: "))

# Processamento
resultado = valor/dolar

# Saída
print ("O valor convertido em dólares é: ",round(resultado) )

# Arredondando para o número mais próximo
# Out:
# Digite o valor da cotação do dólar: 6
# Digite o valor que deseja converter: 5680
# O valor convertido em dólares é:  947

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2 -

# %%
# Coletando valores para as variáveis
n1 = float(input("Digite o primeiro número: "))
n2 = float(input("Digite o segundo número: "))
n3 = float(input("Digite o terceiro número: "))
n4 = float(input("Digite o quarto número: "))

# Processamento
q1 = n1 * n1
q2 = n2 * n2
q3 = n3 * n3
q4 = n4 *n4
soma = q1 + q2 + q3 + q4

#Saída
print ("O resultado é: ",soma)
# Out:
# Digite o primeiro número: 6
# Digite o segundo número: 12
# Digite o terceiro número: 45
# Digite o quarto número: 67
# O resultado é:  6694.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3 -

# %%
# Coletando valores para as variáveis
PP = float(input("Digite o preço unitário por peça: "))
QV = float(input("Digite a quantidade de peças vendidas: "))

# Processamento
SC = PP * QV
CC = SC * 0.05

#Saída
print ("O valor do pagamento com a comissão de 5% é de: ",CC)
# Out:
# Digite o preço unitário por peça: 8
# Digite a quantidade de peças vendidas: 999
# O valor do pagamento com a comissão de 5% é de:  399.6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4 -

# %%
# Coletando valores para as variáveis
CF = float(input("Digite o valor do custo de fábrica: "))

# Processamento
I = CF * 0.45
CFI = CF + I
D = CFI * 0.28
CFD = CFI + D

# Saída
print ("O valor do custo do consumidor é: ",CFD)
# Out:
# Digite o valor do custo de fábrica: 56000
# O valor do custo do consumidor é:  103936.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5 -

# %%
# Coletando valores para as variáveis
H = float(input("Digite as horas: "))
M = float(input("Digite os minutos: "))

#Processamento
MH = M/60
HT = MH + H
S = (HT*60) *60

# Saída
print ("O valor convertido em segundos é: ",round(S))
# Out:
# Digite as horas: 1
# Digite os minutos: 32
# O valor convertido em segundos é:  5520

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6 -

# %%
# Coletando valores para as variáveis
h = float(input("Digite as horas trabalhadas: "))
m = float(input("Digite os minutos trabalhados: "))
por_hora = float(input("Digite o ganho por hora: "))

# Processamento
minutos_horas = m/60
horas_totais = h + minutos_horas
salario_sem = horas_totais * por_hora
salario_com = salario_sem * 0.70
salario_total = salario_com + salario_sem

# Saída
print ("O valor que você deve receber é de: ", round(salario_total,2))
# Out:
# Digite as horas trabalhadas: 6
# Digite os minutos trabalhados: 34
# Digite o ganho por hora: 12
# O valor que você deve receber é de:  133.96

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 7 -

# %%
# Coletando valores para as variáveis
quilometros_percorrer = float(input("Digite os KM a percorrer: "))
consumo_gasolina= float(input("Digite o consumo de gasolina do carro (KM pot Litro): "))
preco_gasolina = float(input("Digite o preço médio da gasolina: "))

# Obtendo resultado da conta
km = quilometros_percorrer / consumo_gasolina
p = km * preco_gasolina

# resultado
print ("O gasto de gasolina para ir é de: ",round(p,2))

# ida e volta
ida_volta = p * 2

# resultado da ida e volta

print ("O gasto para ida e volta é de: ",round(ida_volta,2))
# Out:
# Digite os KM a percorrer: 12
# Digite o consumo de gasolina do carro (KM pot Litro): 4
# Digite o preço médio da gasolina: 6
# O gasto de gasolina para ir é de:  18.0
# O gasto para ida e volta é de:  36.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 8 -

# %%
# Coletando os valores para as variáveis de entrada
distancia = float(input("Digite a distância percorrida: "))
qtde_horas = int(input("Digite a quantidade de horas: "))
qtde_min = int(input("Digite a quantidade de minutos: "))
# Out:
# Digite a distância percorrida: 300
# Digite a quantidade de horas: 4
# Digite a quantidade de minutos: 50

# %%
# Processamento
tempo_total = qtde_horas + (qtde_min/60)
velocidade = distancia/tempo_total

# %%
# Saída do programa
print ("A velocidade média foi de:",round(velocidade,2),"Km/h")
# Out:
# A velocidade média foi de: 62.07 Km/h

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
